# %% [markdown]
# # Introduction To Data Science – Assignment 1
#
# ---
#
# ### Sections A – B – C – D
#
# ---
#
# ***Instructions***
#
# Due Date: Sunday 18th September 2022 – 11:59PM
#
# Name the file in the format Lyyxxxx and save it as .ipynb (e.g. L201234.ipynb)
#
# Submission will be taken on **GitHub and Google Classroom (submit the .ipynb file)** - Instructions to upload onto GitHub are provided in the link https://docs.google.com/document/d/1BR1ULOGeGWJVU6Rr6Qty1FR-quVRZyRvQGII6nEs-wo/edit?usp=sharing
#
# After uploading and submitting the .ipynb file onto Google Classroom, also private comment the link to the GitHub repository.
#
# All source files needed to complete this assignment can be found on the following Google Drive link https://drive.google.com/drive/folders/1VrkaVcExGWqilSeh50WZe4gUBjmUiJ9b?usp=sharing
#
# TA Emails
#
# Section A, C - Muhammad Maarij l192347@lhr.nu.edu.pk
#
# Section B, D - Hira Ijaz l192377@lhr.nu.edu.pk
#
# Happy Coding 😊
#
# ---

# %% [markdown]
# ---
# ## Question 1
# ---

# %% [markdown]
# Define a procedure called "check_input" that takes an input as a square list of lists (2D Matrix of N x N) and returns a boolen "true" if the input is valid or "false" otherwise, according to the following criteria.
#
# 1. Each coloumn must contain numbers from between 1 and N, with no duplicates.
# 2. Each row must contain numbers from between 1 and N, with no duplicates.

# %%
# define procedure here
def check_input(test):
  def check_input(test):
    n=len(test)
    val =0
    for i in range(n):
        for j in range(n):
            val=test[i][j]
            for val in range(1,n):
                for r in range (val):
                    for c in range(r):
                        if(c!=val):
                            return False
                        else:
                            return True

# %%
# run this block to test code after defining the procedure

test1 = [[1, 2, 3],
        [2, 3, 1],
        [3, 1, 2]]

test2 = [[1, 2, 3, 4],
        [2, 3, 1, 3],
        [3, 1, 2, 3],
        [4, 4, 4, 4]]

test3 = [['a', 'b', 'c'],
        ['b', 'c', 'a'],
        ['c', 'a', 'b']]

print(check_input(test1)) # must return true
print(check_input(test2)) # must return false
print(check_input(test3)) # must return false
# Out:
# None
# None
# None

# %% [markdown]
# ---
# ## Question 2
# ---

# %% [markdown]
# **Part A** - Import the file "StudentMarkSheet.csv" as a Pandas DataFrame and print the information for the dataframe

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# **Part B** - Remove any rows that do not contain all the data. Also print the following information.
#
# 1. Number of rows before
# 2. Number of rows containing null data
# 3. Number of rows after

# %%
info=pd.read_csv("/content/gdrive/MyDrive/StudentMarkSheet.csv")

# %%
info.shape[0:]
# Out:
# (200, 4)

# %%
info.drop([49,80,106],axis=0,inplace=True)

# %%
info.shape[0:]
# Out:
# (197, 4)

# %% [markdown]
# **Part C** - Print all the marks along with the subject for the student named "James Walker"

# %%
info[info['Student name']=='James Walker']
# Out:
#      Student name    Exam name   Exam date  Marks
# 0    James Walker      Biology  05/06/2016   31.0
# 42   James Walker    Chemistry  15/06/2016   61.0
# 71   James Walker  Mathematics  29/07/2016   23.0
# 150  James Walker      Physics  10/06/2016  100.0
# 180  James Walker    Sociology  21/06/2016   73.0

# %% [markdown]
# ---
# ## Question 3
# ---

# %% [markdown]
# **Part A** - From the DataFrame created in Question 2, calculate the average marks for each subject

# %%
AverageMarksOfBio = info[info['Exam name']=='Biology']['Marks'].mean()

# %%
AverageMarksOfBio
# Out:
# 47.89473684210526

# %%
AverageMarksOfChem = info[info['Exam name']=='Chemistry']['Marks'].mean()

# %%
AverageMarksOfChem
# Out:
# 52.56

# %%
AverageMarksOfMath = info[info['Exam name']=='Mathematics']['Marks'].mean()

# %%
AverageMarksOfMath
# Out:
# 48.94285714285714

# %%
AverageMarksOfPhil = info[info['Exam name']=='Philosophy']['Marks'].mean()

# %%
AverageMarksOfPhil
# Out:
# 46.833333333333336

# %%
AverageMarksOfPhy = info[info['Exam name']=='Physics']['Marks'].mean()

# %%
AverageMarksOfPhy
# Out:
# 51.76190476190476

# %%
AverageMarksOfSocio = info[info['Exam name']=='Sociology']['Marks'].mean()

# %%
AverageMarksOfSocio
# Out:
# 56.026315789473685

# %% [markdown]
# **Part B** - Using the averages you just calculated, plot a Bar Graph showing the average marks of each subject

# %%
import matplotlib.pyplot as plt
x=["Biology", "Chemistry", "Mathematics", "Philosophy", "Physics", "Sociology"]
y=[47.98,52.56,48.94,46.83,51.76,56.03]
plt.bar(x,y)
plt.xlabel("Subjects")
plt.ylabel("Average Marks")
plt.title("Average Marks Of Subjects")
plt.show()

# %% [markdown]
# ---
# ## Question 4
# ---

# %% [markdown]
# **Part A** - Import the file "CatData.csv" and preprocess it to remove any null values

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')

# %%
info=pd.read_csv("/content/gdrive/MyDrive/CatData.csv")

# %% [markdown]
# **Part B** - Identify the independant and dependant variables (comment answer below)

# %%
# dependant variable: Mass(kg)
# independant variable: Tail Length(cm)

# %% [markdown]
# **Part C** - Create a linear regression model using sklearn and fit it to the data you just imported

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
info=info[['Tail Length (cm)', 'Mass (kg)']]
info.head()
# Out:
#    Tail Length (cm)  Mass (kg)
# 0              18.1       3.75
# 1              18.6       3.80
# 2              19.5       3.25
# 3              19.3       3.45
# 4              19.0       3.65

# %% [markdown]
# **Part D** - Print the values for slope and y-intercept

# %%
x=info["Tail Length (cm)"]
y=info["Mass (kg)"]
slope=np.polyfit(x,y,1)
print (slope)
# Out:
# [ 0.49685566 -5.78083136]

# %% [markdown]
# **Part E** - Plot a scatter graph of the original data and a regression line on the same figure (example with dummy data shown below)
#
# ![](https://drive.google.com/uc?export=view&id=1o_NAsNjfx7zAh9m-UjvWB3rta6uraKdY)

# %%
x=np.array(info['Tail Length (cm)']).reshape(-1,1)
y=np.array(info['Mass (kg)']).reshape(-1,1)
info.dropna(inplace=True)
x_train, x_test,y_train, y_test=train_test_split(x,y,test_size=0.25)
regression=LinearRegression()
regression.fit(x_train,y_train)
print(regression.score(x_test,y_test))
y_prediction=regression.predict(x_test)
plt.scatter(x_test,y_test,color='b')
plt.plot(x_test,y_prediction,color='r')
plt.show()
# Out:
# 0.7732712242904514
